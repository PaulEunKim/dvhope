# %%
import pandas as pd

# %%
df = pd.read_csv("../exploratory_data_analysis/filtered.csv")
# Out:
# C:\Users\Paul\AppData\Local\Temp\ipykernel_15396\1388464918.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../exploratory_data_analysis/filtered.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'State', 'State-County', 'Pollutant',
#        'Emissions (Tons)', 'Pollutant Type', 'Site Name', 'EIS Facility ID',
#        'Facility Type', 'Street Address', 'NAICS', 'Lat/Lon', 'EPA Region',
#        'FIPS', 'StateAbbr_x', 'County_x', 'StateCountyKey', 'Year',
#        'StateAbbr_y', 'StateDesc', 'LocationName', 'DataSource', 'Category',
#        'Measure', 'Data_Value_Unit', 'Data_Value_Type', 'Data_Value',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'TotalPopulation',
#        'TotalPop18plus', 'LocationID', 'CategoryID', 'MeasureId',
#        'DataValueTypeID', 'Short_Question_Text', 'Geolocation', 'County_y',
#        'Pollutant Type_encoded', 'Pollutant_encoded', 'MeasureId_encoded',
#        'CategoryID_encoded', 'TotalPopulation_encoded',
#        'TotalPop18plus_encoded', 'State-County_encoded'],
#       dtype='object')

# %%
df[['Category', 'CategoryID', 'Measure', 'Pollutant']].head()
# Out:
#           Category CategoryID                                     Measure  \
# 0  Health Outcomes    HLTHOUT  Cancer (non-skin) or melanoma among adults
# 1  Health Outcomes    HLTHOUT  Cancer (non-skin) or melanoma among adults
# 2  Health Outcomes    HLTHOUT  Cancer (non-skin) or melanoma among adults
# 3  Health Outcomes    HLTHOUT  Cancer (non-skin) or melanoma among adults
# 4  Health Outcomes    HLTHOUT  Cancer (non-skin) or melanoma among adults
#
#                      Pollutant
# 0               Carbon Dioxide
# 1              Nitrogen Oxides
# 2                      Ammonia
# 3  PM2.5 Primary (Filt + Cond)
# 4   PM10 Primary (Filt + Cond)

# %%
df
# Out:
#          Unnamed: 0.1  Unnamed: 0    State     State-County  \
# 0                  46          46  Alabama     AL - Autauga
# 1                 126         126  Alabama     AL - Autauga
# 2                 206         206  Alabama     AL - Autauga
# 3                 286         286  Alabama     AL - Autauga
# 4                 366         366  Alabama     AL - Autauga
# ...               ...         ...      ...              ...
# 1033560      80274449    80274449  Wyoming  WY - Sweetwater
# 1033561      80274529    80274529  Wyoming  WY - Sweetwater
# 1033562      80274609    80274609  Wyoming  WY - Sweetwater
# 1033563      80274689    80274689  Wyoming  WY - Sweetwater
# 1033564      80274769    80274769  Wyoming  WY - Sweetwater
#
#                            Pollutant  Emissions (Tons) Pollutant Type  \
# 0                     Carbon Dioxide           0.00000            GHG
# 1                    Nitrogen Oxides         211.00000            CAP
# 2                            Ammonia         109.72000            CAP
# 3        PM2.5 Primary (Filt + Cond)          92.40000            CAP
# 4         PM10 Primary (Filt + Cond)          92.40000            CAP
# ...                              ...               ...            ...
# 1033560              Carbon Monoxide           0.00150            CAP
# 1033561             Carbonyl Sulfide           0.00000            HAP
# 1033562                     Methanol           0.00000            HAP
# 1033563   Volatile Organic Compounds          11.14056            CAP
# 1033564                       Hexane           0.21607            HAP
#
#                      Site Name  EIS Facility ID  \
# 0        Alabama Power Company         10708711
# 1        Alabama Power Company         10708711
# 2        Alabama Power Company         10708711
# 3        Alabama Power Company         10708711
# 4        Alabama Power Company         10708711
# ...                        ...              ...
# 1033560    C.G. Road 3-10D PAD         20468011
# 1033561    C.G. Road 3-10D PAD         20468011
# 1033562    C.G. Road 3-10D PAD         20468011
# 1033563    C.G. Road 9-60D PAD         20370011
# 1033564    C.G. Road 9-60D PAD         20370011
#
#                                  Facility Type  ...  \
# 0        Electricity Generation via Combustion  ...
# 1        Electricity Generation via Combustion  ...
# 2        Electricity Generation via Combustion  ...
# 3        Electricity Generation via Combustion  ...
# 4        Electricity Generation via Combustion  ...
# ...                                        ...  ...
# 1033560                            Unspecified  ...
# 1033561                            Unspecified  ...
# 1033562                            Unspecified  ...
# 1033563                            Unspecified  ...
# 1033564                            Unspecified  ...
#
#                    Short_Question_Text  \
# 0        Cancer (non-skin) or Melanoma
# 1        Cancer (non-skin) or Melanoma
# 2        Cancer (non-skin) or Melanoma
# 3        Cancer (non-skin) or Melanoma
# 4        Cancer (non-skin) or Melanoma
# ...                                ...
# 1033560  Cancer (non-skin) or Melanoma
# 1033561  Cancer (non-skin) or Melanoma
# 1033562  Cancer (non-skin) or Melanoma
# 1033563  Cancer (non-skin) or Melanoma
# 1033564  Cancer (non-skin) or Melanoma
#
#                                         Geolocation    County_y  \
# 0        POINT (-86.6428164158396 32.5350016195151)     Autauga
# 1        POINT (-86.6428164158396 32.5350016195151)     Autauga
# 2        POINT (-86.6428164158396 32.5350016195151)     Autauga
# 3        POINT (-86.6428164158396 32.5350016195151)     Autauga
# 4        POINT (-86.6428164158396 32.5350016195151)     Autauga
# ...                                             ...         ...
# 1033560  POINT (-108.879886957441 41.6596981373813)  Sweetwater
# 1033561  POINT (-108.879886957441 41.6596981373813)  Sweetwater
# 1033562  POINT (-108.879886957441 41.6596981373813)  Sweetwater
# 1033563  POINT (-108.879886957441 41.6596981373813)  Sweetwater
# 1033564  POINT (-108.879886957441 41.6596981373813)  Sweetwater
#
#          Pollutant Type_encoded  Pollutant_encoded MeasureId_encoded  \
# 0                             2                 61                 5
# 1                             0                145                 5
# 2                             0                 43                 5
# 3                             0                148                 5
# 4                             0                147                 5
# ...                         ...                ...               ...
# 1033560                       0                 63                 5
# 1033561                       3                 65                 5
# 1033562                       3                126                 5
# 1033563                       0                182                 5
# 1033564                       3                114                 5
#
#         CategoryID_encoded TotalPopulation_encoded  TotalPop18plus_encoded  \
# 0                        1                    2030                    2026
# 1                        1                    2030                    2026
# 2                        1                    2030                    2026
# 3                        1                    2030                    2026
# 4                        1                    2030                    2026
# ...                    ...                     ...                     ...
# 1033560                  1                    1768                    1745
# 1033561                  1                    1768                    1745
# 1033562                  1                    1768                    1745
# 1033563                  1                    1768                    1745
# 1033564                  1                    1768                    1745
#
#         State-County_encoded
# 0                         28
# 1                         28
# 2                         28
# 3                         28
# 4                         28
# ...                      ...
# 1033560                 2941
# 1033561                 2941
# 1033562                 2941
# 1033563                 2941
# 1033564                 2941
#
# [1033565 rows x 48 columns]

# %%
df.groupby('State')['Pollutant'].nunique()
# Out:
# State
# Alabama                 139
# Alaska                   65
# Arizona                 106
# Arkansas                141
# California              147
# Colorado                 99
# Delaware                102
# District Of Columbia     58
# Florida                 111
# Georgia                 112
# Hawaii                   72
# Idaho                    89
# Illinois                129
# Indiana                 117
# Iowa                    119
# Kansas                  123
# Kentucky                138
# Louisiana               143
# Maine                    96
# Maryland                101
# Massachusetts            92
# Michigan                123
# Minnesota               149
# Mississippi             124
# Missouri                124
# Montana                  75
# Nebraska                135
# Nevada                   76
# New Hampshire            83
# New Jersey               95
# New Mexico               91
# New York                133
# North Carolina          138
# North Dakota             78
# Ohio                    151
# Oklahoma                109
# Oregon                  134
# Pennsylvania            128
# Rhode Island            110
# South Carolina          135
# South Dakota             69
# Tennessee               129
# Texas                   174
# Utah                    159
# Vermont                  96
# Virginia                 99
# Washington              110
# West Virginia           123
# Wisconsin               127
# Wyoming                  96
# Name: Pollutant, dtype: int64

# %%
# Count the number of unique states per pollutant
pollutants_per_state = df.groupby('Pollutant')['State'].nunique()

# Get pollutants that appear in all states
shared_pollutants = pollutants_per_state[pollutants_per_state == df['State'].nunique()].index

# Filter the original DataFrame to only include these shared pollutants
df_shared_pollutants = df[df['Pollutant'].isin(shared_pollutants)]

# %%
df_shared_pollutants.groupby('State')['Pollutant'].nunique()
# Out:
# State
# Alabama                 46
# Alaska                  46
# Arizona                 46
# Arkansas                46
# California              46
# Colorado                46
# Delaware                46
# District Of Columbia    46
# Florida                 46
# Georgia                 46
# Hawaii                  46
# Idaho                   46
# Illinois                46
# Indiana                 46
# Iowa                    46
# Kansas                  46
# Kentucky                46
# Louisiana               46
# Maine                   46
# Maryland                46
# Massachusetts           46
# Michigan                46
# Minnesota               46
# Mississippi             46
# Missouri                46
# Montana                 46
# Nebraska                46
# Nevada                  46
# New Hampshire           46
# New Jersey              46
# New Mexico              46
# New York                46
# North Carolina          46
# North Dakota            46
# Ohio                    46
# Oklahoma                46
# Oregon                  46
# Pennsylvania            46
# Rhode Island            46
# South Carolina          46
# South Dakota            46
# Tennessee               46
# Texas                   46
# Utah                    46
# Vermont                 46
# Virginia                46
# Washington              46
# West Virginia           46
# Wisconsin               46
# Wyoming                 46
# Name: Pollutant, dtype: int64

# %%
# Convert 'Emissions (Tons)' to numeric, forcing errors to NaN
df_shared_pollutants['Emissions (Tons)'] = pd.to_numeric(df_shared_pollutants['Emissions (Tons)'], errors='coerce')

# Replace NaN values with 0
df_shared_pollutants['Emissions (Tons)'] = df_shared_pollutants['Emissions (Tons)'].fillna(0)

df_shared_pollutants.groupby('Pollutant')['Emissions (Tons)'].sum().sort_values(ascending=False)
# Out:
# C:\Users\Paul\AppData\Local\Temp\ipykernel_15396\3589952388.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shared_pollutants['Emissions (Tons)'] = pd.to_numeric(df_shared_pollutants['Emissions (Tons)'], errors='coerce')
# C:\Users\Paul\AppData\Local\Temp\ipykernel_15396\3589952388.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shared_pollutants['Emissions (Tons)'] = df_shared_pollutants['Emissions (Tons)'].fillna(0)
# Pollutant
# Carbon Dioxide                 1.996872e+06
# Carbon Monoxide                1.041928e+06
# Nitrogen Oxides                9.902846e+05
# Volatile Organic Compounds     8.137997e+05
# PM10 Primary (Filt + Cond)     4.016383e+05
# Methane                        4.014397e+05
# PM2.5 Primary (Filt + Cond)    3.025374e+05
# Sulfur Dioxide                 2.676890e+05
# Ammonia                        6.004102e+04
# Methanol                       3.890180e+04
# Nitrous Oxide                  3.087772e+04
# Formaldehyde                   2.403815e+04
# Hexane                         2.391727e+04
# Styrene                        1.397670e+04
# Toluene                        1.322040e+04
# Xylenes (Mixed Isomers)        9.234745e+03
# Acetaldehyde                   9.169585e+03
# Benzene                        5.340666e+03
# Acrolein                       3.635134e+03
# Ethylbenzene                   2.397949e+03
# Phenol                         2.283788e+03
# Methyl Isobutyl Ketone         2.215067e+03
# Methylene Chloride             1.900216e+03
# 1,3-Butadiene                  1.369873e+03
# Naphthalene                    1.299857e+03
# Propionaldehyde                7.011669e+02
# 2,2,4-Trimethylpentane         6.454945e+02
# Polycyclic Organic Matter      5.918599e+02
# Manganese Compounds            5.888844e+02
# Chloroform                     5.822458e+02
# Cumene                         5.059397e+02
# Vinyl Chloride                 3.552526e+02
# Lead Compounds                 3.222120e+02
# Chlorobenzene                  2.783645e+02
# Nickel Compounds               2.251930e+02
# Chromium Compounds             1.568869e+02
# Carbon Tetrachloride           1.288376e+02
# Selenium Compounds             1.170636e+02
# Ethyl Chloride                 8.597949e+01
# 1,1,2,2-Tetrachloroethane      5.434568e+01
# 1,4-Dichlorobenzene            5.386541e+01
# Arsenic Compounds              3.657701e+01
# Cobalt Compounds               2.648276e+01
# Mercury Compounds              2.179600e+01
# Cadmium Compounds              1.543275e+01
# Beryllium Compounds            2.985080e+00
# Name: Emissions (Tons), dtype: float64

# %%
df_shared_pollutants.groupby(['Pollutant', 'Pollutant Type'])['Emissions (Tons)'].sum().sort_values(ascending=False)
# Out:
# Pollutant                    Pollutant Type
# Carbon Dioxide               GHG               1.996872e+06
# Carbon Monoxide              CAP               1.041928e+06
# Nitrogen Oxides              CAP               9.902846e+05
# Volatile Organic Compounds   CAP               8.137997e+05
# PM10 Primary (Filt + Cond)   CAP               4.016383e+05
# Methane                      GHG               4.014397e+05
# PM2.5 Primary (Filt + Cond)  CAP               3.025374e+05
# Sulfur Dioxide               CAP               2.676890e+05
# Ammonia                      CAP               6.004102e+04
# Methanol                     HAP               3.890180e+04
# Nitrous Oxide                GHG               3.087772e+04
# Formaldehyde                 HAP               2.403815e+04
# Hexane                       HAP               2.391727e+04
# Styrene                      HAP               1.397670e+04
# Toluene                      HAP               1.322040e+04
# Xylenes (Mixed Isomers)      HAP               9.234745e+03
# Acetaldehyde                 HAP               9.169585e+03
# Benzene                      HAP               5.340666e+03
# Acrolein                     HAP               3.635134e+03
# Ethylbenzene                 HAP               2.397949e+03
# Phenol                       HAP               2.283788e+03
# Methyl Isobutyl Ketone       HAP               2.215067e+03
# Methylene Chloride           HAP               1.900216e+03
# 1,3-Butadiene                HAP               1.369873e+03
# Naphthalene                  HAP               1.299857e+03
# Propionaldehyde              HAP               7.011669e+02
# 2,2,4-Trimethylpentane       HAP               6.454945e+02
# Polycyclic Organic Matter    HAP               5.918599e+02
# Manganese Compounds          HAP               5.888844e+02
# Chloroform                   HAP               5.822458e+02
# Cumene                       HAP               5.059397e+02
# Vinyl Chloride               HAP               3.552526e+02
# Lead Compounds               CAP/HAP           3.222120e+02
# Chlorobenzene                HAP               2.783645e+02
# Nickel Compounds             HAP               2.251930e+02
# Chromium Compounds           HAP               1.568869e+02
# Carbon Tetrachloride         HAP               1.288376e+02
# Selenium Compounds           HAP               1.170636e+02
# Ethyl Chloride               HAP               8.597949e+01
# 1,1,2,2-Tetrachloroethane    HAP               5.434568e+01
# 1,4-Dichlorobenzene          HAP               5.386541e+01
# Arsenic Compounds            HAP               3.657701e+01
# Cobalt Compounds             HAP               2.648276e+01
# Mercury Compounds            HAP               2.179600e+01
# Cadmium Compounds            HAP               1.543275e+01
# Beryllium Compounds          HAP               2.985080e+00
# Name: Emissions (Tons), dtype: float64

# %%
df_shared_pollutants.groupby(['Pollutant', 'State'])['Emissions (Tons)'].count().sort_values(ascending=False)
# Out:
# Pollutant                    State
# Volatile Organic Compounds   California              20050
# Benzene                      California              15568
# Toluene                      California              15272
# PM2.5 Primary (Filt + Cond)  California              15044
# Xylenes (Mixed Isomers)      California              15031
#                                                      ...
# 1,4-Dichlorobenzene          Vermont                     1
# Vinyl Chloride               District Of Columbia        1
# Methylene Chloride           District Of Columbia        1
# Chloroform                   District Of Columbia        1
# 1,4-Dichlorobenzene          Massachusetts               1
# Name: Emissions (Tons), Length: 2300, dtype: int64

# %%
df_shared_pollutants.groupby('State')['Emissions (Tons)'].count()
# Out:
# State
# Alabama                  10431
# Alaska                   13553
# Arizona                   4922
# Arkansas                  6836
# California              233353
# Colorado                 23058
# Delaware                  3081
# District Of Columbia      1041
# Florida                  13849
# Georgia                   8851
# Hawaii                    1154
# Idaho                     4792
# Illinois                 44213
# Indiana                   9237
# Iowa                     10232
# Kansas                   15029
# Kentucky                 21603
# Louisiana                15290
# Maine                     5353
# Maryland                  6080
# Massachusetts            20258
# Michigan                 29326
# Minnesota                49257
# Mississippi               7820
# Missouri                 10656
# Montana                   6090
# Nebraska                  8138
# Nevada                    5747
# New Hampshire             1494
# New Jersey                8616
# New Mexico               34146
# New York                 13045
# North Carolina           13438
# North Dakota              3689
# Ohio                     22204
# Oklahoma                 30042
# Oregon                   12083
# Pennsylvania             26842
# Rhode Island              8730
# South Carolina            9791
# South Dakota              3036
# Tennessee                10488
# Texas                    53968
# Utah                      3934
# Vermont                    794
# Virginia                  4793
# Washington                6742
# West Virginia             5002
# Wisconsin                21753
# Wyoming                  86139
# Name: Emissions (Tons), dtype: int64

# %%
df_shared_pollutants.groupby('State')['Data_Value'].count()
# Out:
# State
# Alabama                  10431
# Alaska                   13553
# Arizona                   4922
# Arkansas                  6836
# California              233353
# Colorado                 23058
# Delaware                  3081
# District Of Columbia      1041
# Florida                  13849
# Georgia                   8851
# Hawaii                    1154
# Idaho                     4792
# Illinois                 44213
# Indiana                   9237
# Iowa                     10232
# Kansas                   15029
# Kentucky                 21603
# Louisiana                15290
# Maine                     5353
# Maryland                  6080
# Massachusetts            20258
# Michigan                 29326
# Minnesota                49257
# Mississippi               7820
# Missouri                 10656
# Montana                   6090
# Nebraska                  8138
# Nevada                    5747
# New Hampshire             1494
# New Jersey                8616
# New Mexico               34146
# New York                 13045
# North Carolina           13438
# North Dakota              3689
# Ohio                     22204
# Oklahoma                 30042
# Oregon                   12083
# Pennsylvania             26842
# Rhode Island              8730
# South Carolina            9791
# South Dakota              3036
# Tennessee                10488
# Texas                    53968
# Utah                      3934
# Vermont                    794
# Virginia                  4793
# Washington                6742
# West Virginia             5002
# Wisconsin                21753
# Wyoming                  86139
# Name: Data_Value, dtype: int64

# %%
df_shared_pollutants.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'State', 'State-County', 'Pollutant',
#        'Emissions (Tons)', 'Pollutant Type', 'Site Name', 'EIS Facility ID',
#        'Facility Type', 'Street Address', 'NAICS', 'Lat/Lon', 'EPA Region',
#        'FIPS', 'StateAbbr_x', 'County_x', 'StateCountyKey', 'Year',
#        'StateAbbr_y', 'StateDesc', 'LocationName', 'DataSource', 'Category',
#        'Measure', 'Data_Value_Unit', 'Data_Value_Type', 'Data_Value',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'TotalPopulation',
#        'TotalPop18plus', 'LocationID', 'CategoryID', 'MeasureId',
#        'DataValueTypeID', 'Short_Question_Text', 'Geolocation', 'County_y',
#        'Pollutant Type_encoded', 'Pollutant_encoded', 'MeasureId_encoded',
#        'CategoryID_encoded', 'TotalPopulation_encoded',
#        'TotalPop18plus_encoded', 'State-County_encoded'],
#       dtype='object')

# %%
# # Pivot the DataFrame without aggregation to make each pollutant a column
# pivot_df = df_shared_pollutants.pivot(index='State-County', columns='Pollutant', values='Emissions (Tons)').fillna(0).reset_index()

# # Include 'State' and 'Data_Value' columns from the original DataFrame
# merged_df = df_shared_pollutants[['State', 'Data_Value']].drop_duplicates().merge(pivot_df, on='State', how='left')

# print(merged_df)

# %%
pivot_df = df_shared_pollutants.pivot_table(
    index='State-County',
    columns='Pollutant',
    values='Emissions (Tons)',
    aggfunc='sum').fillna(0).reset_index()

merged_df = df_shared_pollutants[['State', 'State-County', 'Data_Value'
                                  ]].drop_duplicates().merge(pivot_df,
                                                             on='State-County',
                                                             how='left')

# %%
merged_df
# Out:
#         State     State-County  Data_Value  1,1,2,2-Tetrachloroethane  \
# 0     Alabama     AL - Autauga         7.1                    0.00000
# 1     Alabama     AL - Baldwin         7.5                    0.05800
# 2     Alabama     AL - Barbour         6.2                    0.00000
# 3     Alabama        AL - Bibb         7.1                    0.00000
# 4     Alabama      AL - Blount         7.5                    0.00000
# ...       ...              ...         ...                        ...
# 2941  Wyoming        WY - Park         7.5                    0.01120
# 2942  Wyoming      WY - Platte         7.1                    0.00000
# 2943  Wyoming    WY - Sheridan         7.3                    0.00000
# 2944  Wyoming    WY - Sublette         7.3                    0.10298
# 2945  Wyoming  WY - Sweetwater         7.2                    0.00650
#
#       1,3-Butadiene  1,4-Dichlorobenzene  2,2,4-Trimethylpentane  \
# 0           0.04647              0.43000                 0.06881
# 1           3.09982              0.01000                 0.01103
# 2           0.48014              0.00000                 0.00106
# 3           0.00525              0.00000                 0.00013
# 4           0.00411              0.00000                 0.00010
# ...             ...                  ...                     ...
# 2941        0.21389              0.00000                 0.81460
# 2942        0.01097              0.00000                 0.22262
# 2943        0.05395              0.00000                 0.03168
# 2944        0.84703              0.00006                 9.59629
# 2945       27.28361              0.00000                 1.38146
#
#       Acetaldehyde  Acrolein    Ammonia  ...   Phenol  \
# 0         92.71004   3.97683  214.96000  ...  5.39462
# 1          7.70762   4.39599   18.58000  ...  1.30182
# 2          3.34798   1.96112   68.44500  ...  0.58626
# 3          1.27646   0.58728    0.00000  ...  0.84584
# 4          0.00898   0.00492    0.24400  ...  0.00144
# ...            ...       ...        ...  ...      ...
# 2941       1.53879   1.43849    1.39109  ...  0.03277
# 2942       0.02649   0.01434   74.01796  ...  0.01619
# 2943       0.12250   0.06840    0.01411  ...  0.02000
# 2944      19.43095  12.25880    0.77620  ...  0.08263
# 2945      30.50896  15.19182   19.29413  ...  0.01883
#
#       Polycyclic Organic Matter  Propionaldehyde  Selenium Compounds  Styrene  \
# 0                       0.09633          3.95500             0.00247  1.88926
# 1                       0.48069          1.30819             0.00000  0.58003
# 2                       0.07620          0.21902             0.00045  0.56223
# 3                       0.01095          0.01190             0.00000  0.19112
# 4                       0.00152          0.00149             0.00000  0.00088
# ...                         ...              ...                 ...      ...
# 2941                    0.19079          0.02641             0.00001  0.02288
# 2942                    0.00423          0.00397             0.01266  0.00228
# 2943                    0.01693          0.02048             0.00000  0.01111
# 2944                    0.31524          0.00598             0.00000  0.03101
# 2945                    0.02395          0.03297             0.00003  5.70445
#
#       Sulfur Dioxide    Toluene  Vinyl Chloride  Volatile Organic Compounds  \
# 0          739.33523    6.32599         0.03000                   632.33808
# 1           33.24527    7.05981         0.14400                   186.55555
# 2          178.48868    0.49191         0.00400                   252.98857
# 3            2.57206    0.10189         0.00000                   141.80678
# 4            0.02512    0.00932         0.00000                     0.25859
# ...              ...        ...             ...                         ...
# 2941      1004.59198    9.59617         0.00414                   588.73330
# 2942         2.85017    1.15951         0.00000                   307.06492
# 2943        14.53809    0.12728         0.00000                    14.45773
# 2944        47.98347  266.33800         0.03392                  4994.99166
# 2945        20.86838   49.44752         0.00171                  1367.86259
#
#       Xylenes (Mixed Isomers)
# 0                     4.02363
# 1                     1.98050
# 2                     0.55827
# 3                     0.00692
# 4                     0.00542
# ...                       ...
# 2941                  4.44367
# 2942                  0.67317
# 2943                  0.07977
# 2944                115.24353
# 2945                 14.66043
#
# [2946 rows x 49 columns]

# %%
moved_df = merged_df.copy()  # Optional: Copy to avoid modifying the original
moved_column = moved_df.pop('Data_Value')  # Remove 'Data_Value' from the DataFrame
moved_df['Data_Value'] = moved_column      # Add 'Data_Value' back as the last column

# %%
moved_df.columns
# Out:
# Index(['State', 'State-County', '1,1,2,2-Tetrachloroethane', '1,3-Butadiene',
#        '1,4-Dichlorobenzene', '2,2,4-Trimethylpentane', 'Acetaldehyde',
#        'Acrolein', 'Ammonia', 'Arsenic Compounds', 'Benzene',
#        'Beryllium Compounds', 'Cadmium Compounds', 'Carbon Dioxide',
#        'Carbon Monoxide', 'Carbon Tetrachloride', 'Chlorobenzene',
#        'Chloroform', 'Chromium Compounds', 'Cobalt Compounds', 'Cumene',
#        'Ethyl Chloride', 'Ethylbenzene', 'Formaldehyde', 'Hexane',
#        'Lead Compounds', 'Manganese Compounds', 'Mercury Compounds', 'Methane',
#        'Methanol', 'Methyl Isobutyl Ketone', 'Methylene Chloride',
#        'Naphthalene', 'Nickel Compounds', 'Nitrogen Oxides', 'Nitrous Oxide',
#        'PM10 Primary (Filt + Cond)', 'PM2.5 Primary (Filt + Cond)', 'Phenol',
#        'Polycyclic Organic Matter', 'Propionaldehyde', 'Selenium Compounds',
#        'Styrene', 'Sulfur Dioxide', 'Toluene', 'Vinyl Chloride',
#        'Volatile Organic Compounds', 'Xylenes (Mixed Isomers)', 'Data_Value'],
#       dtype='object')

# %%
moved_df.to_csv('pivoted_cancer.csv', index=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
