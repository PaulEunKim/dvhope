# %%
import os
os.environ["JAVA_HOME"] = r"C:\Program Files\Java\jdk-17"
os.environ["PATH"] = r"C:\Program Files\Java\jdk-17\bin;" + os.environ["PATH"]

# %%
# !java -version
# Out:
# java version "1.8.0_202"
# Java(TM) SE Runtime Environment (build 1.8.0_202-b08)
# Java HotSpot(TM) Client VM (build 25.202-b08, mixed mode)

# %%
import h2o
h2o.init(port=34321)
# Out:
# Checking whether there is an H2O instance running at http://localhost:34321..... not found.
# Attempting to start a local H2O server...
# ; Java HotSpot(TM) Client VM (build 25.202-b08, mixed mode, sharing)
#   Starting server from C:\Users\Paul\anaconda3\envs\h2o\Lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\Paul\AppData\Local\Temp\tmp8pejsp6o
#   JVM stdout: C:\Users\Paul\AppData\Local\Temp\tmp8pejsp6o\h2o_Paul_started_from_python.out
#   JVM stderr: C:\Users\Paul\AppData\Local\Temp\tmp8pejsp6o\h2o_Paul_started_from_python.err
# c:\Users\Paul\anaconda3\envs\h2o\Lib\site-packages\h2o\backend\server.py:395: UserWarning:   You have a 32-bit version of Java. H2O works best with 64-bit Java.
#   Please download the latest 64-bit Java SE JDK from Oracle.
#
#   warn("  You have a 32-bit version of Java. H2O works best with 64-bit Java.\n"
#   Server is running at http://127.0.0.1:34321
# Connecting to H2O server at http://127.0.0.1:34321 ... successful.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         02 secs
# H2O_cluster_timezone:       America/Denver
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.5
# H2O_cluster_version_age:    2 months and 18 days
# H2O_cluster_name:           H2O_from_python_Paul_x9rdgf
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    247.5 Mb
# H2O_cluster_total_cores:    0
# H2O_cluster_allowed_cores:  0
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:34321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.11.9 final
# --------------------------  -----------------------------

# %%
model_path = "../saved_models/GBM_grid_1_AutoML_1_20241113_70146_model_225"
saved_model = h2o.load_model(model_path)

# %%
import pandas as pd
df = pd.read_csv('../data_preprocessing/pivoted_cancer.csv')
df.columns
# Out:
# Index(['State', 'State-County', '1,1,2,2-Tetrachloroethane', '1,3-Butadiene',
#        '1,4-Dichlorobenzene', '2,2,4-Trimethylpentane', 'Acetaldehyde',
#        'Acrolein', 'Ammonia', 'Arsenic Compounds', 'Benzene',
#        'Beryllium Compounds', 'Cadmium Compounds', 'Carbon Dioxide',
#        'Carbon Monoxide', 'Carbon Tetrachloride', 'Chlorobenzene',
#        'Chloroform', 'Chromium Compounds', 'Cobalt Compounds', 'Cumene',
#        'Ethyl Chloride', 'Ethylbenzene', 'Formaldehyde', 'Hexane',
#        'Lead Compounds', 'Manganese Compounds', 'Mercury Compounds', 'Methane',
#        'Methanol', 'Methyl Isobutyl Ketone', 'Methylene Chloride',
#        'Naphthalene', 'Nickel Compounds', 'Nitrogen Oxides', 'Nitrous Oxide',
#        'PM10 Primary (Filt + Cond)', 'PM2.5 Primary (Filt + Cond)', 'Phenol',
#        'Polycyclic Organic Matter', 'Propionaldehyde', 'Selenium Compounds',
#        'Styrene', 'Sulfur Dioxide', 'Toluene', 'Vinyl Chloride',
#        'Volatile Organic Compounds', 'Xylenes (Mixed Isomers)', 'Data_Value'],
#       dtype='object')

# %%
h2o_df = h2o.H2OFrame(df)

splits = h2o_df.split_frame(ratios = [0.8], seed = 1)
train = splits[0]
test = splits[1]
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
predictions = saved_model.predict(test)
print(predictions)
# Out:
# gbm prediction progress: |███████████████████████████████████████████████████████| (done) 100%
#   predict
#   6.86218
#   7.11347
#   6.53439
#   6.75701
#   6.74593
#   6.77077
#   6.72989
#   7.28185
#   6.63527
#   6.497
# [580 rows x 1 column]

# %%
print(saved_model)
# Out:
# Model Details
# =============
# H2OGradientBoostingEstimator : Gradient Boosting Machine
# Model Key: GBM_grid_1_AutoML_1_20241113_70146_model_225
#
#
# Model Summary:
#     number_of_trees    number_of_internal_trees    model_size_in_bytes    min_depth    max_depth    mean_depth    min_leaves    max_leaves    mean_leaves
# --  -----------------  --------------------------  ---------------------  -----------  -----------  ------------  ------------  ------------  -------------
#     43                 43                          21934                  6            6            6             12            41            31
#
# ModelMetricsRegression: gbm
# ** Reported on train data. **
#
# MSE: 0
# Beryllium Compounds         2.184722900390625      0.0012432856600113802   0.0008198850641440865
# Cumene                      2.1275596618652344     0.0012107551112970692   0.0007984327850121683
# Polycyclic Organic Matter   0.6771575808525085     0.0003853579370140672   0.0002541243955989321
# Carbon Tetrachloride        0.35704830288887024    0.0002031896286864395   0.00013399345549233607
# Ethyl Chloride              0.24512824416160583    0.00013949797970964716  9.199198037976859e-05
# [47 rows x 4 columns]

# %%
saved_model.params
# Out:
# {'model_id': {'default': None,
#   'actual': {'__meta': {'schema_version': 3,
#     'schema_name': 'ModelKeyV3',
#     'schema_type': 'Key<Model>'},
#    'name': 'GBM_grid_1_AutoML_1_20241113_70146_model_225',
#    'type': 'Key<Model>',
#    'URL': '/3/Models/GBM_grid_1_AutoML_1_20241113_70146_model_225'},
#   'input': None},
#  'training_frame': {'default': None, 'actual': None, 'input': None},
#  'validation_frame': {'default': None, 'actual': None, 'input': None},
#  'nfolds': {'default': 0, 'actual': 5, 'input': 5},
#  'keep_cross_validation_models': {'default': True,
#   'actual': False,
#   'input': False},
#  'keep_cross_validation_predictions': {'default': False,
#   'actual': True,
#   'input': True},
#  'keep_cross_validation_fold_assignment': {'default': False,
#   'actual': False,
#   'input': False},
#  'score_each_iteration': {'default': False, 'actual': False, 'input': False},
#  'score_tree_interval': {'default': 0, 'actual': 5, 'input': 5},
#  'fold_assignment': {'default': 'AUTO', 'actual': 'Modulo', 'input': 'Modulo'},
#  'fold_column': {'default': None, 'actual': None, 'input': None},
#  'response_column': {'default': None,
#   'actual': {'__meta': {'schema_version': 3,
#     'schema_name': 'ColSpecifierV3',
#     'schema_type': 'VecSpecifier'},
#    'column_name': 'Data_Value',
#    'is_member_of_frames': None},
#   'input': {'__meta': {'schema_version': 3,
#     'schema_name': 'ColSpecifierV3',
#     'schema_type': 'VecSpecifier'},
#    'column_name': 'Data_Value',
#    'is_member_of_frames': None}},
#  'ignored_columns': {'default': None, 'actual': None, 'input': None},
#  'ignore_const_cols': {'default': True, 'actual': True, 'input': True},
#  'offset_column': {'default': None, 'actual': None, 'input': None},
#  'weights_column': {'default': None, 'actual': None, 'input': None},
#  'balance_classes': {'default': False, 'actual': False, 'input': False},
#  'class_sampling_factors': {'default': None, 'actual': None, 'input': None},
#  'max_after_balance_size': {'default': 5.0, 'actual': 5.0, 'input': 5.0},
#  'max_confusion_matrix_size': {'default': 20, 'actual': 20, 'input': 20},
#  'ntrees': {'default': 50, 'actual': 43, 'input': 10000},
#  'max_depth': {'default': 5, 'actual': 6, 'input': 6},
#  'min_rows': {'default': 10.0, 'actual': 15.0, 'input': 15.0},
#  'nbins': {'default': 20, 'actual': 20, 'input': 20},
#  'nbins_top_level': {'default': 1024, 'actual': 1024, 'input': 1024},
#  'nbins_cats': {'default': 1024, 'actual': 1024, 'input': 1024},
#  'r2_stopping': {'default': 1.7976931348623157e+308,
#   'actual': 1.7976931348623157e+308,
#   'input': 1.7976931348623157e+308},
#  'stopping_rounds': {'default': 0, 'actual': 0, 'input': 3},
#  'stopping_metric': {'default': 'AUTO',
#   'actual': 'deviance',
#   'input': 'deviance'},
#  'stopping_tolerance': {'default': 0.001,
#   'actual': 0.020558557070186494,
#   'input': 0.020558557070186494},
#  'max_runtime_secs': {'default': 0.0, 'actual': 106.40625, 'input': 85.125},
#  'seed': {'default': -1, 'actual': 200, 'input': 200},
#  'build_tree_one_node': {'default': False, 'actual': False, 'input': False},
#  'learn_rate': {'default': 0.1, 'actual': 0.1, 'input': 0.1},
#  'learn_rate_annealing': {'default': 1.0, 'actual': 1.0, 'input': 1.0},
#  'distribution': {'default': 'AUTO',
#   'actual': 'gaussian',
#   'input': 'gaussian'},
#  'quantile_alpha': {'default': 0.5, 'actual': 0.5, 'input': 0.5},
#  'tweedie_power': {'default': 1.5, 'actual': 1.5, 'input': 1.5},
#  'huber_alpha': {'default': 0.9, 'actual': 0.9, 'input': 0.9},
#  'checkpoint': {'default': None, 'actual': None, 'input': None},
#  'sample_rate': {'default': 1.0, 'actual': 0.9, 'input': 0.9},
#  'sample_rate_per_class': {'default': None, 'actual': None, 'input': None},
#  'col_sample_rate': {'default': 1.0, 'actual': 0.7, 'input': 0.7},
#  'col_sample_rate_change_per_level': {'default': 1.0,
#   'actual': 1.0,
#   'input': 1.0},
#  'col_sample_rate_per_tree': {'default': 1.0, 'actual': 0.7, 'input': 0.7},
#  'min_split_improvement': {'default': 1e-05,
#   'actual': 0.0001,
#   'input': 0.0001},
#  'histogram_type': {'default': 'AUTO',
#   'actual': 'UniformAdaptive',
#   'input': 'AUTO'},
#  'max_abs_leafnode_pred': {'default': 1.7976931348623157e+308,
#   'actual': 1.7976931348623157e+308,
#   'input': 1.7976931348623157e+308},
#  'pred_noise_bandwidth': {'default': 0.0, 'actual': 0.0, 'input': 0.0},
#  'categorical_encoding': {'default': 'AUTO',
#   'actual': 'Enum',
#   'input': 'AUTO'},
#  'calibrate_model': {'default': False, 'actual': False, 'input': False},
#  'calibration_frame': {'default': None, 'actual': None, 'input': None},
#  'calibration_method': {'default': 'AUTO',
#   'actual': 'PlattScaling',
#   'input': 'AUTO'},
#  'custom_metric_func': {'default': None, 'actual': None, 'input': None},
#  'custom_distribution_func': {'default': None, 'actual': None, 'input': None},
#  'export_checkpoints_dir': {'default': None, 'actual': None, 'input': None},
#  'in_training_checkpoints_dir': {'default': None,
#   'actual': None,
#   'input': None},
#  'in_training_checkpoints_tree_interval': {'default': 1,
#   'actual': 1,
#   'input': 1},
#  'monotone_constraints': {'default': None, 'actual': None, 'input': None},
#  'check_constant_response': {'default': True, 'actual': True, 'input': True},
#  'gainslift_bins': {'default': -1, 'actual': -1, 'input': -1},
#  'auc_type': {'default': 'AUTO', 'actual': 'AUTO', 'input': 'AUTO'},
#  'interaction_constraints': {'default': None, 'actual': None, 'input': None},
#  'auto_rebalance': {'default': True, 'actual': True, 'input': True}}

# %%
from h2o.tree import H2OTree

for tree_number in range(saved_model.ntrees):
    print(f"Plotting Tree {tree_number + 1}/{saved_model.ntrees}")
    tree = H2OTree(model=saved_model, tree_number=tree_number, tree_class=None)
    print(tree)  # Displays tree structure in text
# Out:
# Plotting Tree 1/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 0, tree class is 'None'
#
#
# Plotting Tree 2/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 1, tree class is 'None'
#
#
# Plotting Tree 3/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 2, tree class is 'None'
#
#
# Plotting Tree 4/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 3, tree class is 'None'
#
#
# Plotting Tree 5/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 4, tree class is 'None'
#
#
# Plotting Tree 6/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 5, tree class is 'None'
#
#
# Plotting Tree 7/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 6, tree class is 'None'
#
#
# Plotting Tree 8/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 7, tree class is 'None'
#
#
# Plotting Tree 9/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 8, tree class is 'None'
#
#
# Plotting Tree 10/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 9, tree class is 'None'
#
#
# Plotting Tree 11/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 10, tree class is 'None'
#
#
# Plotting Tree 12/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 11, tree class is 'None'
#
#
# Plotting Tree 13/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 12, tree class is 'None'
#
#
# Plotting Tree 14/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 13, tree class is 'None'
#
#
# Plotting Tree 15/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 14, tree class is 'None'
#
#
# Plotting Tree 16/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 15, tree class is 'None'
#
#
# Plotting Tree 17/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 16, tree class is 'None'
#
#
# Plotting Tree 18/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 17, tree class is 'None'
#
#
# Plotting Tree 19/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 18, tree class is 'None'
#
#
# Plotting Tree 20/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 19, tree class is 'None'
#
#
# Plotting Tree 21/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 20, tree class is 'None'
#
#
# Plotting Tree 22/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 21, tree class is 'None'
#
#
# Plotting Tree 23/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 22, tree class is 'None'
#
#
# Plotting Tree 24/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 23, tree class is 'None'
#
#
# Plotting Tree 25/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 24, tree class is 'None'
#
#
# Plotting Tree 26/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 25, tree class is 'None'
#
#
# Plotting Tree 27/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 26, tree class is 'None'
#
#
# Plotting Tree 28/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 27, tree class is 'None'
#
#
# Plotting Tree 29/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 28, tree class is 'None'
#
#
# Plotting Tree 30/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 29, tree class is 'None'
#
#
# Plotting Tree 31/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 30, tree class is 'None'
#
#
# Plotting Tree 32/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 31, tree class is 'None'
#
#
# Plotting Tree 33/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 32, tree class is 'None'
#
#
# Plotting Tree 34/50
# Tree related to model GBM_grid_1_AutoML_1_20241113_70146_model_225. Tree number is 33, tree class is 'None'
#
#
# Plotting Tree 35/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 5
#       3 for tree_number in range(saved_model.ntrees):
#       4     print(f"Plotting Tree {tree_number + 1}/{saved_model.ntrees}")
# ----> 5     tree = H2OTree(model=saved_model, tree_number=tree_number, tree_class=None)
#       6     print(tree)  # Displays tree structure in text
#
# File c:\Users\Paul\anaconda3\envs\h2o\Lib\site-packages\h2o\tree\tree.py:78, in H2OTree.__init__(self, model, tree_number, tree_class, plain_language_rules)
#      73 def __init__(self, model, tree_number, tree_class=None, plain_language_rules="AUTO"):
#      74     params = {"model": model.model_id,
#      75               "tree_number": tree_number,
#      76               "tree_class": tree_class,
#      77               "plain_language_rules": plain_language_rules}
# ---> 78     response = h2o.api(endpoint="GET /3/Tree", data=params)
#      80     self._left_children = response['left_children']
#      81     self._right_children = response['right_children']
#
# File c:\Users\Paul\anaconda3\envs\h2o\Lib\site-packages\h2o\h2o.py:123, in api(endpoint, data, json, filename, save_to)
#     121 # type checks are performed in H2OConnection class
#     122 _check_connection()
# --> 123 return h2oconn.request(endpoint, data=data, json=json, filename=filename, save_to=save_to)
#
# File c:\Users\Paul\anaconda3\envs\h2o\Lib\site-packages\h2o\backend\connection.py:494, in H2OConnection.request(self, endpoint, data, json, filename, save_to)
#     492 self._log_start_transaction(endpoint, rd, json, filename, params)
#     493 args = self._request_args()
# --> 494 resp = requests.request(method=method, url=url, data=rd, json=json, params=params,
#     495                         stream=stream, **args)
#     496 if isinstance(save_to, types.FunctionType):
#     497     save_to = save_to(resp)
#
# File c:\Users\Paul\anaconda3\envs\h2o\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Paul\anaconda3\envs\h2o\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Paul\anaconda3\envs\h2o\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Paul\anaconda3\envs\h2o\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\Paul\anaconda3\envs\h2o\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\Paul\anaconda3\envs\h2o\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\Paul\anaconda3\envs\h2o\Lib\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\Paul\anaconda3\envs\h2o\Lib\http\client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File c:\Users\Paul\anaconda3\envs\h2o\Lib\http\client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File c:\Users\Paul\anaconda3\envs\h2o\Lib\http\client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File c:\Users\Paul\anaconda3\envs\h2o\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
from h2o.tree import H2OTree
from h2o.tree import H2OTreeGraph

# Save visual representations
for tree_number in range(saved_model.ntrees):
    print(f"Saving Tree {tree_number + 1}/{saved_model.ntrees}")
    tree_graph = H2OTreeGraph(model=saved_model, tree_number=tree_number)
    tree_graph.view()
